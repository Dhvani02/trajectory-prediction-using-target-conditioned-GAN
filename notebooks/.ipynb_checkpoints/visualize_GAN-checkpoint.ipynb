# %%
from typing import Dict

from tempfile import gettempdir
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import torch


import l5kit
from l5kit.configs import load_config_data
from l5kit.data import LocalDataManager, ChunkedDataset
from l5kit.dataset import AgentDataset, EgoDataset
from l5kit.rasterization import build_rasterizer
from l5kit.evaluation import write_pred_csv, compute_metrics_csv, read_gt_csv, create_chopped_dataset
from l5kit.evaluation.chop_dataset import MIN_FUTURE_STEPS
from l5kit.evaluation.metrics import neg_multi_log_likelihood, time_displace
from l5kit.geometry import transform_points
from l5kit.visualization import PREDICTED_POINTS_COLOR, TARGET_POINTS_COLOR, draw_trajectory
from prettytable import PrettyTable
from pathlib import Path

import matplotlib.pyplot as plt

import os
import random
import time

import warnings
warnings.filterwarnings("ignore")

import pytorch_lightning as pl
from argparse import Namespace
import numpy as np
from omegaconf import DictConfig
import torch.nn as nn
import torch
from torch.utils.data import DataLoader
from data.collect_data import TrajectoryDataset, seq_collate
from models.model_main import get_model
from models.pytorch_script import TrajPredictor


from l5kit.data import LocalDataManager, ChunkedDataset
from l5kit.dataset import AgentDataset, EgoDataset
from l5kit.rasterization import build_rasterizer

from pytorch_lightning import Trainer, seed_everything
import os
from pytorch_lightning.loggers import TensorBoardLogger

from pytorch_lightning.callbacks import ModelCheckpoint
import logging
import torch

# %% [markdown]
# ## Target vs Predicted

# %%
# load trained model from checkpoint directory

model = TrajPredictor.load_from_checkpoint("../saved_weights/trained-checkpoint-goalgan/_ckpt_epoch_47.ckpt")
# Out:
# GoalGAN(
#   (encoder): MotionEncoder(
#     (spatial_embedding): Linear(in_features=2, out_features=8, bias=True)
#     (encoder): LSTM(8, 16)
#   )
#   (goalmodule): GoalGlobal(
#     (CNN): CNN(
#       (encoder): Sequential(
#         (ConvBlock_1): Conv_Blocks(
#           (Block): Sequential(
#             (Conv_1): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (BN_1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (NonLin_1): ReLU()
#             (Pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=(1, 1), ceil_mode=False)
#             (Drop): Dropout2d(p=0.3, inplace=False)
#           )
#         )
#         (ConvBlock_2): Conv_Blocks(
#           (Block): Sequential(
#             (Conv_1): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (BN_1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (NonLin_1): ReLU()
#             (Pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=(1, 1), ceil_mode=False)
#             (Drop): Dropout2d(p=0.3, inplace=False)
#           )
#         )
#         (ConvBlock_3): Conv_Blocks(
#           (Block): Sequential(
#             (Conv_1): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (BN_1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (NonLin_1): ReLU()
#             (Pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=(1, 1), ceil_mode=False)
#             (Drop): Dropout2d(p=0.3, inplace=False)
#           )
#         )
#       )
#       (decoder): Sequential(
#         (UpConv_1): UpConv_Blocks(
#           (Block): Sequential(
#             (UpConv): ConvTranspose2d(17, 16, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#             (BN_up): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (NonLin_up): ReLU()
#             (Drop_up): Dropout2d(p=0.3, inplace=False)
#           )
#         )
#         (UpConv_2): UpConv_Blocks(
#           (Block): Sequential(
#             (UpConv): ConvTranspose2d(32, 8, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#             (BN_up): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (NonLin_up): ReLU()
#             (Drop_up): Dropout2d(p=0.3, inplace=False)
#           )
#         )
#         (UpConv_3): UpConv_Blocks(
#           (Block): Sequential(
#             (UpConv): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(2, 2))
#           )
#         )
#       )
#       (traj2cnn): Sequential(
#         (0): Linear(in_features=16, out_features=32, bias=True)
#         (1): Tanh()
#         (2): Linear(in_features=32, out_features=9, bias=True)
#         (3): Tanh()
#       )
#     )
#     (gumbelsampler): GumbelSampler(
#       (gumbelsoftmax): GumbelSoftmax()
#       (gumbel_map): get_gumbel_map()
#     )
#   )
#   (final_pos_embedding): Sequential(
#     (0): Linear(in_features=2, out_features=4, bias=True)
#     (1): Tanh()
#   )
#   (routingmodule): RoutingModule(
#     (rm_attention): AttentionRoutingModule(
#       (CNN): CNN(
#         (encoder): Sequential(
#           (ConvBlock_1): Conv_Blocks(
#             (Block): Sequential(
#               (Conv_1): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (BN_1): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (NonLin_1): ReLU()
#               (Pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=(1, 1), ceil_mode=False)
#             )
#           )
#           (ConvBlock_2): Conv_Blocks(
#             (Block): Sequential(
#               (Conv_1): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (BN_1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (NonLin_1): ReLU()
#               (Pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=(1, 1), ceil_mode=False)
#             )
#           )
#           (ConvBlock_3): Conv_Blocks(
#             (Block): Sequential(
#               (Conv_1): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#               (BN_1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               (NonLin_1): ReLU()
#               (Pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=(1, 1), ceil_mode=False)
#             )
#           )
#         )
#         (traj2cnn): Sequential(
#           (0): Linear(in_features=16, out_features=32, bias=True)
#           (1): Tanh()
#           (2): Linear(in_features=32, out_features=4, bias=True)
#           (3): Tanh()
#         )
#       )
#       (cnn_attention): Sequential(
#         (0): Linear(in_features=8, out_features=32, bias=True)
#         (1): LeakyReLU(negative_slope=0.01)
#         (2): Linear(in_features=32, out_features=1, bias=True)
#       )
#     )
#     (final_output): Sequential(
#       (0): Linear(in_features=28, out_features=32, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=32, out_features=2, bias=True)
#     )
#     (spatial_embedding): Linear(in_features=2, out_features=8, bias=True)
#     (decoder): LSTM(17, 16)
#   )
#   (encoder2decoder): Sequential(
#     (0): Linear(in_features=20, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=32, out_features=16, bias=True)
#     (3): Tanh()
#   )
# )
# GoalGANDiscriminator(
#   (encoder_observation): MotionEncoder(
#     (spatial_embedding): Linear(in_features=2, out_features=8, bias=True)
#     (encoder): LSTM(8, 16)
#   )
#   (EncoderPrediction): EncoderPrediction(
#     (encoder_out): Conv2d(8, 1, kernel_size=(1, 1), stride=(1, 1))
#     (leakyrelu): LeakyReLU(negative_slope=0.01)
#     (inputFeatures): Sequential(
#       (0): Linear(in_features=12, out_features=32, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Dropout(p=0.3, inplace=False)
#       (3): Linear(in_features=32, out_features=8, bias=True)
#     )
#     (encoder): LSTM(8, 16, dropout=0.3)
#     (CNN): CNN(
#       (encoder): Sequential(
#         (ConvBlock_1): Conv_Blocks(
#           (Block): Sequential(
#             (Conv_1): Conv2d(4, 4, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (BN_1): BatchNorm2d(4, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (NonLin_1): ReLU()
#             (Pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=(1, 1), ceil_mode=False)
#             (Drop): Dropout2d(p=0.3, inplace=False)
#           )
#         )
#         (ConvBlock_2): Conv_Blocks(
#           (Block): Sequential(
#             (Conv_1): Conv2d(4, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (BN_1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (NonLin_1): ReLU()
#             (Pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=(1, 1), ceil_mode=False)
#             (Drop): Dropout2d(p=0.3, inplace=False)
#           )
#         )
#         (ConvBlock_3): Conv_Blocks(
#           (Block): Sequential(
#             (Conv_1): Conv2d(8, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#             (BN_1): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (NonLin_1): ReLU()
#             (Pool): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=(1, 1), ceil_mode=False)
#             (Drop): Dropout2d(p=0.3, inplace=False)
#           )
#         )
#       )
#     )
#     (spatial_embedding): Linear(in_features=2, out_features=8, bias=True)
#     (real_classifier): Sequential(
#       (0): Linear(in_features=16, out_features=32, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Dropout(p=0.3, inplace=False)
#       (3): Linear(in_features=32, out_features=1, bias=True)
#     )
#   )
# )

# %%
test = TrajectoryDataset(phase='test')
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))

# %%
# sample a batch of data from the test set = ground truth
temp = seq_collate(test)

# sets the model to train mode 
model.generator.gen()

# pass a batch of data to the trained model = predicted
ans = model(temp)

# %% [markdown]
# ### Real vs Predicted Trajectories

# %%
# create a scatter plot of predicted vs target trajectories

plot_index = 126
fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.scatter(temp["gt_xy"].permute(1,0,2)[plot_index,:,0], temp["gt_xy"].permute(1,0,2)[plot_index,:,1],color="red",label="ground truth")
ax1.scatter(ans["out_xy"].permute(1,0,2)[plot_index,:,0].detach().numpy(), ans["out_xy"].permute(1,0,2)[plot_index,:,1].detach().numpy(),color="pink",label="predicted")   
plt.legend(loc='best',fontsize=14)
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
# plot real and target on the raster image

fig = plt.figure(figsize=(8,8))
ax1 = fig.add_subplot(111)
img_scaling = cfg['img_scaling']
ax1.scatter(temp["in_xy"].permute(1,0,2)[plot_index,:,0]/img_scaling, temp["in_xy"].permute(1,0,2)[plot_index,:,1]/img_scaling,color="yellow",label="history ",s=20)
ax1.scatter(temp["gt_xy"].permute(1,0,2)[plot_index,:,0]/img_scaling, temp["gt_xy"].permute(1,0,2)[plot_index,:,1]/img_scaling,color="red",label="future ground truth")
ax1.scatter(ans["out_xy"].permute(1,0,2)[plot_index,:,0].detach().numpy()/img_scaling, ans["out_xy"].permute(1,0,2)[plot_index,:,1].detach().numpy()/img_scaling,color="pink",label="predicted")   

plt.imshow(temp["scene_img"][plot_index]["local_image"])
plt.legend(loc='best',fontsize=16)
plt.show()

# %%
# display sample with top 3 modes depicting power of multi-modality

plot_index = 27
fig = plt.figure(figsize=(8,8))
ax1 = fig.add_subplot(111)
img_scaling = cfg['img_scaling']
ax1.scatter(temp["in_xy"].permute(1,0,2)[plot_index,:,0]/img_scaling, temp["in_xy"].permute(1,0,2)[plot_index,:,1]/img_scaling,color="yellow",label="history ",s=20)
ax1.scatter(temp["out_xy"][0].permute(1,0,2)[plot_index,:,0]/img_scaling, temp["out_xy"][0].permute(1,0,2)[plot_index,:,1]/img_scaling,color="brown",label="mode1")
ax1.scatter(temp["out_xy"][1].permute(1,0,2)[plot_index,:,0]/img_scaling, temp["out_xy"][0].permute(1,0,2)[plot_index,:,1]/img_scaling,color="red",label="mode2")
ax1.scatter(temp["out_xy"][2].permute(1,0,2)[plot_index,:,0]/img_scaling, temp["out_xy"][0].permute(1,0,2)[plot_index,:,1]/img_scaling,color="pink",label="mode3")

plt.imshow(temp["scene_img"][plot_index]["local_image"])
plt.legend(loc='best',fontsize=16)
plt.show()

# %%
# display probability distribution of the
plt.imshow(ans["y_map"][plot_index][0].detach().numpy())
